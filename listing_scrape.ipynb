# %% [markdown]
# 1.Import all libraries and scraping one
# 2. Import all libraries we used for SQL Lite
# 3. Query our database and retrieve all entries
# 4. For each entry we'll scrape the listing date, listing price from URL that's in database
# 5. Update database

# %%
from bs4 import BeautifulSoup
import requests
import sqlite3
conn = sqlite3.connect('sanfrancisco.db')
import datetime
import time

# %%
# !pip install splinter
from splinter import Browser
from bs4 import BeautifulSoup
# !which chromedriver
import time
# Out:
# Requirement already satisfied: splinter in /anaconda3/lib/python3.7/site-packages (0.10.0)
# Requirement already satisfied: selenium>=3.141.0 in /anaconda3/lib/python3.7/site-packages (from splinter) (3.141.0)
# Requirement already satisfied: urllib3 in /anaconda3/lib/python3.7/site-packages (from selenium>=3.141.0->splinter) (1.23)
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path' : '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
def scrape(url):

#     url = 'https://www.redfin.com/city/17151/CA/San-Francisco/filter/property-type=house,min-beds=3,min-baths=2,include=sold-3mo'
    browser.visit(url)
    time.sleep(2)
    
    html=browser.html
    soup=BeautifulSoup(html, 'html.parser')
    
    
    headers = {'User-Agent': "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9"}
    response = requests.get(url, headers=headers)



    soup = BeautifulSoup(response.text,'html.parser')
    results = soup.find_all('span', class_="entryItemContent")
    

    original_price=None
    for result in results:
        try:
            index = result.text.find("Original Price: ")
            if index != -1:
                price=result.text[16:len(result.text)]
                print(price)
                original_price=int(float(price.replace(',','').replace('$','')))
                print("Original Price: " + (str(original_price)))
                  
                break
      
        except AttributeError as e:
            print(e)
            
    print(original_price)
    
    listing_date=None
    for result in results:
        try:
            search_string = "On Market Date: "
            index = result.text.find(search_string)
            if index != -1:
                listing_date=result.text[len(search_string):len(result.text)]
                print("Listing Date: " + (str(listing_date)))
                listing_date=int(datetime.datetime.strptime(listing_date,"%A, %B %d, %Y").strftime("%s"))

                break

        except AttributeError as e:
                print(e)
                print(listing_date)
    return original_price, listing_date

# %%
c = conn.cursor()
c.execute("SELECT Address, URL FROM Address WHERE Original_Price IS Null")

rows = c.fetchall()
iteration = 1

missing_data = [
#     "2924 Rivera St",
#     "1230 5th Ave",
#     "87 Melrose Ave",
#     "2211 44th Ave",
#     "860 De Haro St",
#     "701 Quintara St",
#     "345 Holly Park Cir",
#     "160 Anderson St",
#     "156 Midcrest Way",
#     "51 Somerset St",
#     "2038 20th Ave",
#     "1727 31st Ave",
#     "2271 40th Ave",
#     "525 Holloway Ave",
#     "34 Wanda St"
]

for row in rows:
    address = row[0]
    
    # Missing data on web page
    if address in missing_data:
        continue
    
    url = row[1]
    print(address)
    print(url)
    print(row)
    
    redfin=scrape(url)
    original_price = redfin[0]
    listing_date = redfin[1]
    
    c.execute('''UPDATE Address SET Original_Price = ? , Listing_date = ? WHERE Address = ?
            ''', (original_price,listing_date,address))
    conn.commit()

    print("Completed " + str(iteration) + " of " + str(len(rows)) + "...")
    iteration += 1
    
    if iteration > 50:
        print("stopping iterations...")
        break
    
    time.sleep(15)
# Out:
# 2211 44th Ave
# http://www.redfin.com/CA/San-Francisco/2211-44th-Ave-94116/home/655039
# ('2211 44th Ave', 'http://www.redfin.com/CA/San-Francisco/2211-44th-Ave-94116/home/655039')
# None
# Completed 1 of 27...
# 701 Quintara St
# http://www.redfin.com/CA/San-Francisco/701-Quintara-St-94116/home/1101521
# ('701 Quintara St', 'http://www.redfin.com/CA/San-Francisco/701-Quintara-St-94116/home/1101521')
# None
# Completed 2 of 27...
# 235 14th Ave
# http://www.redfin.com/CA/San-Francisco/235-14th-Ave-94118/home/1959516
# ('235 14th Ave', 'http://www.redfin.com/CA/San-Francisco/235-14th-Ave-94118/home/1959516')
# None
# Completed 3 of 27...
# 1326 &1328 44th Ave
# http://www.redfin.com/CA/San-Francisco/1328-44th-Ave-94122/home/154103675
# ('1326 &1328 44th Ave', 'http://www.redfin.com/CA/San-Francisco/1328-44th-Ave-94122/home/154103675')
# None
# Completed 4 of 27...
# 58 Apollo St
# http://www.redfin.com/CA/San-Francisco/58-Apollo-St-94124/home/1862336
# ('58 Apollo St', 'http://www.redfin.com/CA/San-Francisco/58-Apollo-St-94124/home/1862336')
# None
# Completed 5 of 27...
# 2924 Rivera St
# http://www.redfin.com/CA/San-Francisco/2924-Rivera-St-94116/home/652243
# ('2924 Rivera St', 'http://www.redfin.com/CA/San-Francisco/2924-Rivera-St-94116/home/652243')
# None
# Completed 6 of 27...
# 2162 43rd Ave
# http://www.redfin.com/CA/San-Francisco/2162-43rd-Ave-94116/home/1636564
# ('2162 43rd Ave', 'http://www.redfin.com/CA/San-Francisco/2162-43rd-Ave-94116/home/1636564')
# None
# Completed 7 of 27...
# 581 Arch St
# http://www.redfin.com/CA/San-Francisco/581-Arch-St-94132/home/1195509
# ('581 Arch St', 'http://www.redfin.com/CA/San-Francisco/581-Arch-St-94132/home/1195509')
# None
# Completed 8 of 27...
# 345 Holly Park Cir
# http://www.redfin.com/CA/San-Francisco/345-Holly-Park-Cir-94110/home/1815122
# ('345 Holly Park Cir', 'http://www.redfin.com/CA/San-Francisco/345-Holly-Park-Cir-94110/home/1815122')
# None
# Completed 9 of 27...
# 160 Anderson St
# http://www.redfin.com/CA/San-Francisco/160-Anderson-St-94110/home/1912109
# ('160 Anderson St', 'http://www.redfin.com/CA/San-Francisco/160-Anderson-St-94110/home/1912109')
# None
# Completed 10 of 27...
# 860 De Haro St
# http://www.redfin.com/CA/San-Francisco/860-De-Haro-St-94107/home/1121615
# ('860 De Haro St', 'http://www.redfin.com/CA/San-Francisco/860-De-Haro-St-94107/home/1121615')
# None
# Completed 11 of 27...
# 1767 31st Ave
# http://www.redfin.com/CA/San-Francisco/1767-31st-Ave-94122/home/640793
# ('1767 31st Ave', 'http://www.redfin.com/CA/San-Francisco/1767-31st-Ave-94122/home/640793')
# None
# Completed 12 of 27...
# 2566 Great Hwy
# http://www.redfin.com/CA/San-Francisco/2566-Great-Hwy-94116/home/664959
# ('2566 Great Hwy', 'http://www.redfin.com/CA/San-Francisco/2566-Great-Hwy-94116/home/664959')
# None
# Completed 13 of 27...
# 156 Midcrest Way
# http://www.redfin.com/CA/San-Francisco/156-Midcrest-Way-94131/home/1766581
# ('156 Midcrest Way', 'http://www.redfin.com/CA/San-Francisco/156-Midcrest-Way-94131/home/1766581')
# None
# Completed 14 of 27...
# 90 Miraloma Dr
# http://www.redfin.com/CA/San-Francisco/90-Miraloma-Dr-94127/home/1590481
# ('90 Miraloma Dr', 'http://www.redfin.com/CA/San-Francisco/90-Miraloma-Dr-94127/home/1590481')
# None
# Completed 15 of 27...
# 1230 5th Ave
# http://www.redfin.com/CA/San-Francisco/1230-5th-Ave-94122/home/626847
# ('1230 5th Ave', 'http://www.redfin.com/CA/San-Francisco/1230-5th-Ave-94122/home/626847')
# None
# Completed 16 of 27...
# 1727 31st Ave
# http://www.redfin.com/CA/San-Francisco/1727-31st-Ave-94122/home/1173929
# ('1727 31st Ave', 'http://www.redfin.com/CA/San-Francisco/1727-31st-Ave-94122/home/1173929')
# None
# Completed 17 of 27...
# 2038 20th Ave
# http://www.redfin.com/CA/San-Francisco/2038-20th-Ave-94116/home/648174
# ('2038 20th Ave', 'http://www.redfin.com/CA/San-Francisco/2038-20th-Ave-94116/home/648174')
# None
# Completed 18 of 27...
# 179 Skyview Way
# http://www.redfin.com/CA/San-Francisco/179-Skyview-Way-94131/home/677729
# ('179 Skyview Way', 'http://www.redfin.com/CA/San-Francisco/179-Skyview-Way-94131/home/677729')
# None
# Completed 19 of 27...
# 406 Douglass St #406
# http://www.redfin.com/CA/San-Francisco/406-Douglass-St-94114/unit-406/home/1943978
# ('406 Douglass St #406', 'http://www.redfin.com/CA/San-Francisco/406-Douglass-St-94114/unit-406/home/1943978')
# None
# Completed 20 of 27...
# 1190 Palou Ave
# http://www.redfin.com/CA/San-Francisco/1190-Palou-Ave-94124/home/1807076
# ('1190 Palou Ave', 'http://www.redfin.com/CA/San-Francisco/1190-Palou-Ave-94124/home/1807076')
# None
# Completed 21 of 27...
# 2271 40th Ave
# http://www.redfin.com/CA/San-Francisco/2271-40th-Ave-94116/home/1092387
# ('2271 40th Ave', 'http://www.redfin.com/CA/San-Francisco/2271-40th-Ave-94116/home/1092387')
# None
# Completed 22 of 27...
# 34 Wanda St
# http://www.redfin.com/CA/San-Francisco/34-Wanda-St-94112/home/1440540
# ('34 Wanda St', 'http://www.redfin.com/CA/San-Francisco/34-Wanda-St-94112/home/1440540')
# None
# Completed 23 of 27...
# 525 Holloway Ave
# http://www.redfin.com/CA/San-Francisco/525-Holloway-Ave-94112/home/996826
# ('525 Holloway Ave', 'http://www.redfin.com/CA/San-Francisco/525-Holloway-Ave-94112/home/996826')
# None
# Completed 24 of 27...
# 1434 42nd Ave
# http://www.redfin.com/CA/San-Francisco/1434-42nd-Ave-94122/home/1916326
# ('1434 42nd Ave', 'http://www.redfin.com/CA/San-Francisco/1434-42nd-Ave-94122/home/1916326')
# None
# Completed 25 of 27...
# 2 Brentwood Ave
# http://www.redfin.com/CA/San-Francisco/2-Brentwood-Ave-94127/home/1597125
# ('2 Brentwood Ave', 'http://www.redfin.com/CA/San-Francisco/2-Brentwood-Ave-94127/home/1597125')
# None
# Completed 26 of 27...
# 46 Cotter St
# http://www.redfin.com/CA/San-Francisco/46-Cotter-St-94112/home/1785491
# ('46 Cotter St', 'http://www.redfin.com/CA/San-Francisco/46-Cotter-St-94112/home/1785491')
# None
# Completed 27 of 27...

# %%
#Parse the string to add the Listing Price/Sold Price
# Talk about the bot detection of Redfin
